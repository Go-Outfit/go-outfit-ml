# %%
import os
import csv
import shutil

# %%
dir_path = "../dataset_resized/"
list_dir = os.path
root_dirs = []
male_dirs = []
female_dirs = []
count = 0
# for root, directory, files in os.walk(dir_path):
#     if len(directory) == 0:
#         continue
#     if count == 0:
#         root_dirs.append(directory)
#         count += 1
#         continue
#     if count == 1:
#         male_dirs.append(directory)
#         count += 1
#         continue
#     if count == 2:
#         female_dirs.append(directory)
#         count += 1
#         break
# print(root_dirs)
# print(male_dirs)
# print(female_dirs)

folder_tree = {}

def insert_files_to_dict(sub_data: dict, files: list, key: str):
    sub_data[key] = files

def insert_folder_to_dict(sub_data: dict, key: str):
    sub_data[key] = {}
    return sub_data

folders = []
files_data = []
for root, dirs, files in os.walk(dir_path):
    folder = root.split("/")[2]
    # skip empty folder
    if len(folder) == 0:
        continue
    # split sub folder
    folder = folder.split("\\")
    if len(files) == 0:
        continue
    files_data.append(files)
    if len(folder) == 1:
        folder.insert(0,"all")
    folders.append(folder)
# Out:
# [['all', 'Jacket'], ['Laki-laki', 'Celana_panjang_cowo'], ['Laki-laki', 'celana_pendek'], ['Laki-laki', 'jas'], ['Laki-laki', 'kaos_cowok'], ['Laki-laki', 'pantofel'], ['Laki-laki', 'sandal'], ['Perempuan', 'cp_cewe'], ['Perempuan', 'dress'], ['Perempuan', 'heels'], ['Perempuan', 'jas_cewe'], ['Perempuan', 'kaos_cewe'], ['Perempuan', 'onepiece'], ['Perempuan', 'pantofel_cewe'], ['Perempuan', 'rok_formal'], ['Perempuan', 'rok_non'], ['Perempuan', 'sandal'], ['all', 'sneakers']]
# [['jacket1281280_resized.jpg', 'jacket128128100_resized.jpg', 'jacket128128101_resized.jpg', 'jacket128128102_resized.jpg', 'jacket128128103_resized.jpg', 'jacket128128104_resized.jpg', 'jacket128128105_resized.jpg', 'jacket128128106_resized.jpg', 'jacket128128107_resized.jpg', 'jacket128128108_resized.jpg', 'jacket128128109_resized.jpg', 'jacket12812810_resized.jpg', 'jacket128128110_resized.jpg', 'jacket128128111_resized.jpg', 'jacket128128112_resized.jpg', 'jacket128128113_resized.jpg', 'jacket128128114_resized.jpg', 'jacket128128115_resized.jpg', 'jacket128128116_resized.jpg', 'jacket128128117_resized.jpg', 'jacket128128118_resized.jpg', 'jacket128128119_resized.jpg', 'jacket12812811_resized.jpg', 'jacket128128120_resized.jpg', 'jacket128128121_resized.jpg', 'jacket128128122_resized.jpg', 'jacket128128123_resized.jpg', 'jacket128128124_resized.jpg', 'jacket128128125_resized.jpg', 'jacket128128126_resized.jpg', 'jacket128128127_resized.jpg', 'jacket128128128_resized.jpg', 'jacket128128129_resized.jpg', 'jacket12812812_resized.jpg', 'jacket128128130_resized.jpg', 'jacket128128131_resized.jpg', 'jacket128128132_resized.jpg', 'jacket128128133_resized.jpg', 'jacket128128134_resized.jpg', 'jacket128128135_resized.jpg', 'jacket128128136_resized.jpg', 'jacket128128137_resized.jpg', 'jacket128128138_resized.jpg', 'jacket128128139_resized.jpg', 'jacket12812813_resized.jpg', 'jacket128128140_resized.jpg', 'jacket128128141_resized.jpg', 'jacket128128142_resized.jpg', 'jacket128128143_resized.jpg', 'jacket128128144_resized.jpg', 'jacket128128145_resized.jpg', 'jacket128128146_resized.jpg', 'jacket128128147_resized.jpg', 'jacket128128148_resized.jpg', 'jacket128128149_resized.jpg', 'jacket12812814_resized.jpg', 'jacket128128150_resized.jpg', 'jacket128128151_resized.jpg', 'jacket128128152_resized.jpg', 'jacket128128153_resized.jpg', 'jacket128128154_resized.jpg', 'jacket128128155_resized.jpg', 'jacket128128156_resized.jpg', 'jacket128128157_resized.jpg', 'jacket128128158_resized.jpg', 'jacket128128159_resized.jpg', 'jacket12812815_resized.jpg', 'jacket128128160_resized.jpg', 'jacket128128161_resized.jpg', 'jacket128128162_resized.jpg', 'jacket128128163_resized.jpg', 'jacket128128164_resized.jpg', 'jacket128128165_resized.jpg', 'jacket128128166_resized.jpg', 'jacket128128167_resized.jpg', 'jacket128128168_resized.jpg', 'jacket128128169_resized.jpg', 'jacket12812816_resized.jpg', 'jacket128128170_resized.jpg', 'jacket128128171_resized.jpg', 'jacket128128172_resized.jpg', 'jacket128128173_resized.jpg', 'jacket128128174_resized.jpg', 'jacket128128175_resized.jpg', 'jacket128128176_resized.jpg', 'jacket128128177_resized.jpg', 'jacket128128178_resized.jpg', 'jacket128128179_resized.jpg', 'jacket12812817_resized.jpg', 'jacket128128180_resized.jpg', 'jacket128128181_resized.jpg', 'jacket128128182_resized.jpg', 'jacket128128183_resized.jpg', 'jacket128128184_resized.jpg', 'jacket128128185_resized.jpg', 'jacket128128186_resized.jpg', 'jacket128128187_resized.jpg', 'jacket128128188_resized.jpg', 'jacket128128189_resized.jpg', 'jacket12812818_resized.jpg', 'jacket128128190_resized.jpg', 'jacket128128191_resized.jpg', 'jacket128128192_resized.jpg', 'jacket128128193_resized.jpg', 'jacket128128194_resized.jpg', 'jacket128128195_resized.jpg', 'jacket128128196_resized.jpg', 'jacket128128197_resized.jpg', 'jacket128128198_resized.jpg', 'jacket128128199_resized.jpg', 'jacket12812819_resized.jpg', 'jacket1281281_resized.jpg', 'jacket128128200_resized.jpg', 'jacket12812820_resized.jpg', 'jacket12812821_resized.jpg', 'jacket12812822_resized.jpg', 'jacket12812823_resized.jpg', 'jacket12812824_resized.jpg', 'jacket12812825_resized.jpg', 'jacket12812826_resized.jpg', 'jacket12812827_resized.jpg', 'jacket12812828_resized.jpg', 'jacket12812829_resized.jpg', 'jacket1281282_resized.jpg', 'jacket12812830_resized.jpg', 'jacket12812831_resized.jpg', 'jacket12812832_resized.jpg', 'jacket12812833_resized.jpg', 'jacket12812834_resized.jpg', 'jacket12812835_resized.jpg',  ...

# %%
header = ["file_name","gender","category"]

path_to_csv = "../deploy/data.csv"
path_to_csv_dir = "../deploy"

listdirs = os.listdir(path_to_csv_dir)
if "data.csv" in listdirs:
    print("File found")
    
    shutil.rmtree(path_to_csv)


file = open(path_to_csv,"a+")
file.close()

with open(path_to_csv, 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(header)

    for index, item in enumerate(folders):
        for index,file in enumerate(files_data[index]):
            dataset = [file]
            for it in item:
                dataset.append(it)
            writer.writerow(dataset)
            

    # write the data
